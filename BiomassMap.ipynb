# %%
import ee
# Trigger the authentication flow.
ee.Authenticate()

# Initialize the library.
ee.Initialize()
# Out:
# To authorize access needed by Earth Engine, open the following URL in a web browser and follow the instructions. If the web browser does not start automatically, please manually browse the URL below.
#
#     https://accounts.google.com/o/oauth2/auth?client_id=517222506229-vsmmajv00ul0bs7p89v5m89qs8eb9359.apps.googleusercontent.com&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fearthengine+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.full_control&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&response_type=code&code_challenge=04R_6t2o0BxYXuU32kxkQdrnViOxKa41uLBVHVXVjHE&code_challenge_method=S256
#
# The authorization workflow will generate a code, which you should paste in the box below.
# Enter verification code: 4/1AX4XfWih6SRK9XL8ti6skfpFzSuwJCyqSDGAqV0RMxHARMKxxM44uxMDc_g
#
# Successfully saved authorization token.

# %%
#initialize map area
lat = 41.8781
lon = -87.6298

# Import aboveground biomass carbon density
bm = ee.Image("NASA/ORNL/biomass_carbon_density/v1/2010")

url = bm.getThumbUrl({'opacity': .8,
  'bands': ['agb'],
  'min': -50,
  'max': 80,
  'palette': ['d9f0a3', 'addd8e', '78c679', '41ab5d', '238443', '005a32'],
  'dimensions': 512,
  'region': ee.Geometry.Rectangle([-89,41,-87, 43.0])
})

#41.7200° N, 87.7480° W

print(url)
from IPython.display import Image

# Display the thumbnail land surface temperature in France.
print('\nPlease wait while the thumbnail loads, it may take a moment...')
Image(url=url)
# Out:
# https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/5aabfd5db40da2ec621976eb8ab41018-13d96f22cd5e5b52d5aa862100b6cf6c:getPixels
#
# Please wait while the thumbnail loads, it may take a moment...
# <img src="https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/5aabfd5db40da2ec621976eb8ab41018-13d96f22cd5e5b52d5aa862100b6cf6c:getPixels"/>
